# %%
import pandas as pd
import numpy as np

# %%
cols = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
data = pd.read_csv("eda.txt", names=cols)

# %%
data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %%
data.shape
# Out:
# (205, 26)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data.sample(10)
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 204         -1                95       volvo       gas      turbo
# 190          3               256  volkswagen       gas        std
# 88          -1               137  mitsubishi       gas        std
# 197         -1                74       volvo       gas        std
# 65           0               118       mazda       gas        std
# 160          0                91      toyota       gas        std
# 87           1               125  mitsubishi       gas      turbo
# 126          3                 ?     porsche       gas        std
# 96           1               122      nissan       gas        std
# 64           0               115       mazda       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 204         four      sedan          rwd           front       109.1  ...
# 190          two  hatchback          fwd           front        94.5  ...
# ...

# %%
data['normalized-losses']=data['normalized-losses'].replace('?', np.NaN)

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          0
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  0
# stroke                0
# compression-ratio     0
# horsepower            0
# peak-rpm              0
# city-mpg              0
# highway-mpg           0
# price                 0
# dtype: int64

# %%
data=data.replace('?', np.NaN)

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
data['normalized-losses']= data['normalized-losses'].astype(float)

# %%
data['normalized-losses'].describe().T
# Out:
# count    164.000000
# mean     122.000000
# std       35.442168
# min       65.000000
# 25%       94.000000
# 50%      115.000000
# 75%      150.000000
# max      256.000000
# Name: normalized-losses, dtype: float64

# %%
data['normalized-losses']= data['normalized-losses'].replace(np.NaN, data['normalized-losses'].mean())

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
data['bore']= data['bore'].astype('float')

# %%
data.bore.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 205 entries, 0 to 204
# Series name: bore
# Non-Null Count  Dtype
# --------------  -----
# 201 non-null    float64
# dtypes: float64(1)
# memory usage: 1.7 KB

# %%
data['bore'].replace(np.NaN, data['bore'].mean(), inplace = True)

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
##changing multiple columns at one time

data[['stroke','horsepower']]= data[['stroke','horsepower']].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    float64
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
data['stroke']= data['stroke'].replace(np.NaN,data['stroke'].mean())

# %%
data.stroke.isnull().sum()
# Out:
# 0

# %%
data['horsepower']= data['horsepower'].replace(np.NaN,data['horsepower'].mean())

# %%
data.horsepower.isnull().sum()
# Out:
# 0

# %%
data.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.465190   -0.531954 -0.357612
# normalized-losses   0.465190           1.000000   -0.056518  0.019209
# wheel-base         -0.531954          -0.056518    1.000000  0.874587
# length             -0.357612           0.019209    0.874587  1.000000
# width              -0.232919           0.084195    0.795144  0.841118
# height             -0.541038          -0.370706    0.589435  0.491029
# curb-weight        -0.227691           0.097785    0.776386  0.877728
# engine-size        -0.105790           0.110997    0.569329  0.683360
# bore               -0.130083          -0.029266    0.488760  0.606462
# stroke             -0.008689           0.054929    0.160944  0.129522
# compression-ratio  -0.178515          -0.114525    0.249786  0.158414
# horsepower          0.071389           0.203434    0.351957  0.554434
# ...

# %%
data[['bore','stroke' ,'compression-ratio','horsepower']].corr().T
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055909           0.005201    0.575737
# stroke            -0.055909  1.000000           0.186105    0.088264
# compression-ratio  0.005201  0.186105           1.000000   -0.205740
# horsepower         0.575737  0.088264          -0.205740    1.000000

# %%
data.dropna(subset = ['price'], axis = 0, inplace = True)
data.shape
# Out:
# (201, 26)

# %%
# Out:
#      symboling normalized-losses        make fuel-type aspiration  \
# 9            0                 ?        audi       gas      turbo
# 164          1               168      toyota       gas        std
# 155          0                91      toyota       gas        std
# 166          1               168      toyota       gas        std
# 124          3                 ?    plymouth       gas      turbo
# 144          0               102      subaru       gas        std
# 157          0                91      toyota       gas        std
# 77           2               161  mitsubishi       gas        std
# 101          0               128      nissan       gas        std
# 53           1               113       mazda       gas        std
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  ...  \
# 9            two  hatchback          4wd           front        99.5  ...
# 164          two  hatchback          rwd           front        94.5  ...
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns
# %matplotlib inline

# %%
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
data["price"] = data["price"].astype("float")

# %%
sns.regplot(y = 'price', x = 'engine-size', data = data)
# Out:
# <AxesSubplot:xlabel='engine-size', ylabel='price'>

# %%
data[['engine-size','price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
sns.regplot(x = 'highway-mpg', y = 'price', data = data)
# Out:
# <AxesSubplot:xlabel='highway-mpg', ylabel='price'>

# %%
data['highway-mpg'].corr(data['price'])
# Out:
# -0.704692265058953

# %%
sns.boxplot(x = 'body-style', y = 'price', data = data)
# Out:
# <AxesSubplot:xlabel='body-style', ylabel='price'>

# %%
sns.relplot(x='price', y='engine-size', hue='body-style', data= data)

# %%
sns.pairplot(data= data, vars=['price', 'engine-size','body-style'])

# %%
sns.displot(data.price, bins=10)

# %%
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
data['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %%
data['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
data.columns= data.columns.str.replace('va','drive-wheels')

# %%
data.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          3                122  alfa-romero       gas        std
# 2          1                122  alfa-romero       gas        std
# 3          2                164         audi       gas        std
# 4          2                164         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible         None           front        88.6  ...
# 1          two  convertible         None           front        88.6  ...
# 2          two    hatchback         None           front        94.5  ...
# 3         four        sedan         None           front        99.8  ...
# 4         four        sedan         None           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
import numpy as np
height= np.round(np.random.normal(1.75, 0.20, 7000), 2)
weight= np.round(np.random.normal(300, 200, 7000), 2)

# %%
height
# Out:
# array([1.57, 1.48, 1.49, ..., 1.82, 1.7 , 1.95])

# %%
weight
# Out:
# array([137.53, 194.23, 500.64, ..., 391.23, 432.8 , 143.71])

# %%
import matplotlib.pyplot as plt
plt.scatter(height,weight)

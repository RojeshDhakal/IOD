# %%
import numpy as np
np.random.normal(3,2,5)
# Out:
# array([-0.55196009,  1.39362699,  1.32986461,  3.83305224,  2.52110503])

# %% [markdown]
# random.normal gives the random number. the first number is mean and second is std and 3rd number is the size. rows and colums can be generated by specifying in paranathesis

# %%
np.random.normal(3,2,(4,4))
# Out:
# array([[ 2.41622175,  3.36796231,  4.59562288, -0.88059095],
#        [ 3.53887341,  1.60911441,  4.21193867,  2.50634072],
#        [ 1.70845988,  6.88827959,  0.77450067,  2.76834509],
#        [ 4.53044641,  3.29624789,  3.13987419,  2.97702693]])

# %%
np.random.randint(0,50,10)
# Out:
# array([28,  5, 18, 10, 12,  8, 11, 14, 31,  4])

# %% [markdown]
# The above code will generate 10 random numbers between 0 and 50. the first number is lowest, second is the highest and 3rd is the size

# %%
np.round(np.random.normal(3,2,5))
# Out:
# array([3., 4., 6., 3., 5.])

# %% [markdown]
# there is no decimal value if you dont specify anything and if you specify you will get decimal value

# %%
np.round(np.random.normal(3,2,5),3)
# Out:
# array([2.903, 4.992, 3.084, 1.539, 4.548])

# %%
a=np.round(np.random.normal(3,2,10),)

# %%
a
# Out:
# array([ 6.,  2.,  2.,  3.,  5.,  3.,  3.,  2.,  6., -0.])

# %%
a.itemsize
# Out:
# 8

# %%
a.min()
# Out:
# -0.0

# %%
a.max()
# Out:
# 6.0

# %%
plt.hist(a)
# Out:
# (array([1., 0., 0., 3., 0., 3., 0., 0., 1., 2.]),
#  array([0. , 0.6, 1.2, 1.8, 2.4, 3. , 3.6, 4.2, 4.8, 5.4, 6. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(a)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x21797188a90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2179719a070>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x217971887c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2179719a610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2179719a8e0>],
#  'means': []}

# %%
df = pd.read_csv("../DATA/Employee-attrition.csv")

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.isna().sum()
# Out:
# EmployeeID             0
# recorddate_key         0
# birthdate_key          0
# orighiredate_key       0
# terminationdate_key    0
# age                    0
# length_of_service      0
# city_name              0
# department_name        0
# job_title              0
# store_name             0
# gender_short           0
# gender_full            0
# termreason_desc        0
# termtype_desc          0
# STATUS_YEAR            0
# STATUS                 0
# BUSINESS_UNIT          0
# dtype: int64

# %%
df.values
# Out:
# array([[1318, '12/31/2006 0:00', '1/3/1954', ..., 2006, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2007 0:00', '1/3/1954', ..., 2007, 'ACTIVE',
#         'HEADOFFICE'],
#        [1318, '12/31/2008 0:00', '1/3/1954', ..., 2008, 'ACTIVE',
#         'HEADOFFICE'],
#        ...,
#        [8279, '12/1/2015 0:00', '7/18/1994', ..., 2015, 'TERMINATED',
#         'STORES'],
#        [8296, '12/1/2013 0:00', '9/2/1994', ..., 2013, 'TERMINATED',
#         'STORES'],
#        [8321, '12/1/2014 0:00', '11/28/1994', ..., 2014, 'TERMINATED',
#         'STORES']], dtype=object)

# %%
df.dtypes
# Out:
# EmployeeID              int64
# recorddate_key         object
# birthdate_key          object
# orighiredate_key       object
# terminationdate_key    object
# age                     int64
# length_of_service       int64
# city_name              object
# department_name        object
# job_title              object
# store_name              int64
# gender_short           object
# gender_full            object
# termreason_desc        object
# termtype_desc          object
# STATUS_YEAR             int64
# STATUS                 object
# BUSINESS_UNIT          object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object    13
# int64      5
# dtype: int64

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.job_title
# Out:
# 0                 CEO
# 1                 CEO
# 2                 CEO
# 3                 CEO
# 4                 CEO
#              ...
# 49648    Dairy Person
# 49649         Cashier
# 49650         Cashier
# 49651         Cashier
# 49652         Cashier
# Name: job_title, Length: 49653, dtype: object

# %%
df.job_title.value_counts()
# Out:
# Meat Cutter                        9984
# Dairy Person                       8590
# Produce Clerk                      8237
# Baker                              8096
# Cashier                            6816
# Shelf Stocker                      5622
# Customer Service Manager            306
# Processed Foods Manager             289
# Bakery Manager                      285
# Meats Manager                       285
# Produce Manager                     278
# Store Manager                       271
# Recruiter                            62
# HRIS Analyst                         55
# Accounting Clerk                     50
# Benefits Admin                       35
# Labor Relations Analyst              30
# Accounts Receiveable Clerk           30
# Trainer                              26
# Accounts Payable Clerk               25
# Auditor                              20
# Systems Analyst                      20
# Investment Analyst                   20
# ...

# %%
df.describe().T
# Out:
#                      count         mean          std     min     25%     50%  \
# EmployeeID         49653.0  4859.495740  1826.571142  1318.0  3360.0  5031.0
# age                49653.0    42.077035    12.427257    19.0    31.0    42.0
# length_of_service  49653.0    10.434596     6.325286     0.0     5.0    10.0
# store_name         49653.0    27.297605    13.514134     1.0    16.0    28.0
# STATUS_YEAR        49653.0  2010.612612     2.845577  2006.0  2008.0  2011.0
#
#                       75%     max
# EmployeeID         6335.0  8336.0
# age                  53.0    65.0
# length_of_service    15.0    26.0
# store_name           42.0    46.0
# STATUS_YEAR        2013.0  2015.0

# %%
df.head()
# Out:
#    EmployeeID   recorddate_key birthdate_key orighiredate_key  \
# 0        1318  12/31/2006 0:00      1/3/1954        8/28/1989
# 1        1318  12/31/2007 0:00      1/3/1954        8/28/1989
# 2        1318  12/31/2008 0:00      1/3/1954        8/28/1989
# 3        1318  12/31/2009 0:00      1/3/1954        8/28/1989
# 4        1318  12/31/2010 0:00      1/3/1954        8/28/1989
#
#   terminationdate_key  age  length_of_service  city_name department_name  \
# 0            1/1/1900   52                 17  Vancouver       Executive
# 1            1/1/1900   53                 18  Vancouver       Executive
# 2            1/1/1900   54                 19  Vancouver       Executive
# 3            1/1/1900   55                 20  Vancouver       Executive
# 4            1/1/1900   56                 21  Vancouver       Executive
#
#   job_title  store_name gender_short gender_full termreason_desc  \
# 0       CEO          35            M        Male  Not Applicable
# ...

# %%
df.set_index("EmployeeID", inplace=True)

# %%
df.head()
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
#
#            department_name job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive       CEO          35            M        Male
# ...

# %%
df.loc[1318]
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# 1318        12/31/2011 0:00      1/3/1954        8/28/1989
# 1318        12/31/2012 0:00      1/3/1954        8/28/1989
# 1318        12/31/2013 0:00      1/3/1954        8/28/1989
# 1318        12/31/2014 0:00      1/3/1954        8/28/1989
# 1318        12/31/2015 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# ...

# %%
df.sort_index()
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# ...                     ...           ...              ...
# 8335        12/31/2013 0:00    12/28/1994       12/10/2013
# 8335        12/31/2015 0:00    12/28/1994       12/10/2013
# 8336        12/31/2015 0:00    12/31/1994       12/11/2013
# 8336        12/31/2013 0:00    12/31/1994       12/11/2013
# 8336        12/31/2014 0:00    12/31/1994       12/11/2013
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# ...

# %%
df.sort_values(['age'], ascending=False)
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 2800          6/1/2007 0:00      6/3/1942        12/9/1993
# 2674          2/1/2007 0:00     2/11/1942        8/19/1993
# 2598         11/1/2006 0:00    11/22/1941        5/30/1993
# 2599         11/1/2006 0:00    11/25/1941         6/2/1993
# 2608         12/1/2006 0:00     12/1/1941         6/8/1993
# ...                     ...           ...              ...
# 8283        12/31/2013 0:00     8/11/1994        9/27/2013
# 8222        12/31/2013 0:00      2/1/1994        6/18/2013
# 8221        12/31/2013 0:00     1/28/1994        6/16/2013
# 8284        12/31/2013 0:00     8/10/1994        9/27/2013
# 8304        12/31/2013 0:00     10/7/1994       10/27/2013
#
#            terminationdate_key  age  length_of_service        city_name  \
# EmployeeID
# 2800                  6/3/2007   65                 13    Prince George
# 2674                 2/11/2007   65                 13          Kelowna
# ...

# %% [markdown]
# If you want to sort the value by specific columns use df.sort_values(['column_name'])

# %%
df.head()
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# 1318                  1/1/1900   55                 20  Vancouver
# 1318                  1/1/1900   56                 21  Vancouver
#
#            department_name job_title  store_name gender_short gender_full  \
# EmployeeID
# 1318             Executive       CEO          35            M        Male
# ...

# %%
df.loc[df.job_title=='CEO',:].sort_values(['age'])
# Out:
#              recorddate_key birthdate_key orighiredate_key  \
# EmployeeID
# 1318        12/31/2006 0:00      1/3/1954        8/28/1989
# 1318        12/31/2007 0:00      1/3/1954        8/28/1989
# 1318        12/31/2008 0:00      1/3/1954        8/28/1989
# 1318        12/31/2009 0:00      1/3/1954        8/28/1989
# 1318        12/31/2010 0:00      1/3/1954        8/28/1989
# 1318        12/31/2011 0:00      1/3/1954        8/28/1989
# 1318        12/31/2012 0:00      1/3/1954        8/28/1989
# 1318        12/31/2013 0:00      1/3/1954        8/28/1989
# 1318        12/31/2014 0:00      1/3/1954        8/28/1989
# 1318        12/31/2015 0:00      1/3/1954        8/28/1989
#
#            terminationdate_key  age  length_of_service  city_name  \
# EmployeeID
# 1318                  1/1/1900   52                 17  Vancouver
# 1318                  1/1/1900   53                 18  Vancouver
# 1318                  1/1/1900   54                 19  Vancouver
# ...

# %%
df.groupby(['age']).size()
# Out:
# age
# 19     158
# 20     408
# 21     703
# 22     815
# 23     960
# 24    1111
# 25    1197
# 26    1210
# 27    1235
# 28    1225
# 29    1227
# 30    1212
# 31    1146
# 32    1153
# 33    1164
# 34    1188
# 35    1189
# 36    1176
# 37    1149
# 38    1156
# 39    1142
# 40    1130
# 41    1135
# 42    1152
# 43    1150
# 44    1157
# 45    1141
# 46    1161
# 47    1173
# 48    1180
# 49    1196
# 50    1218
# 51    1207
# 52    1188
# 53    1188
# 54    1159
# 55    1168
# 56    1154
# 57    1130
# 58    1130
# 59    1128
# 60    1109
# 61     757
# 62     712
# 63     667
# 64     646
# 65     593
# dtype: int64

# %% [markdown]
# the above code will count the same age group and add it. If there is two people who is 19 then it will add the result as 2.

# %%
plt.hist(df.age, facecolor='blue', histtype='barstacked', alpha=0.25, bins=50)
# Out:
# (array([ 158.,  408.,  703.,  815.,  960., 1111., 1197., 1210., 1235.,
#         1225., 1227., 1212.,    0., 1146., 1153., 1164., 1188., 1189.,
#         1176., 1149., 1156., 1142., 1130., 1135.,    0., 1152., 1150.,
#         1157., 1141., 1161., 1173., 1180., 1196., 1218., 1207., 1188.,
#         1188.,    0., 1159., 1168., 1154., 1130., 1130., 1128., 1109.,
#          757.,  712.,  667.,  646.,  593.]),
#  array([19.  , 19.92, 20.84, 21.76, 22.68, 23.6 , 24.52, 25.44, 26.36,
#         27.28, 28.2 , 29.12, 30.04, 30.96, 31.88, 32.8 , 33.72, 34.64,
#         35.56, 36.48, 37.4 , 38.32, 39.24, 40.16, 41.08, 42.  , 42.92,
#         43.84, 44.76, 45.68, 46.6 , 47.52, 48.44, 49.36, 50.28, 51.2 ,
#         52.12, 53.04, 53.96, 54.88, 55.8 , 56.72, 57.64, 58.56, 59.48,
#         60.4 , 61.32, 62.24, 63.16, 64.08, 65.  ]),
#  <BarContainer object of 50 artists>)

# %%
from scipy import stats
stats.describe(df.age)
# Out:
# DescribeResult(nobs=49653, minmax=(19, 65), mean=42.077034620264634, variance=154.43672646776537, skewness=0.023093117697645202, kurtosis=-1.1473302603578608)

# %% [markdown]
# it will desrcibe the skewness and kurtosis aswell

# %%
np.percentile(a,q=[25,50,60,75,100])
# Out:
# array([2. , 3. , 3. , 4.5, 6. ])

# %%
binomial = stats.binom.pmf(k,n,p)

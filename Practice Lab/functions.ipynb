# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic= pd.read_csv('../Data/titanic_train.csv')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.hist(bins=10, figsize=(14,12))
# Out:
# array([[<AxesSubplot:title={'center':'PassengerId'}>,
#         <AxesSubplot:title={'center':'Survived'}>,
#         <AxesSubplot:title={'center':'Pclass'}>],
#        [<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'SibSp'}>,
#         <AxesSubplot:title={'center':'Parch'}>],
#        [<AxesSubplot:title={'center':'Fare'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
titanic1= titanic.drop(["PassengerId",'SibSp','Parch','Fare','Embarked','Ticket', 'Cabin'], axis=1)

# %%
titanic1.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age
# 0    male  22.0
# 1  female  38.0
# 2  female  26.0
# 3  female  35.0
# 4    male  35.0

# %%
titanic.columns=titanic.columns.str.lower()

# %%
titanic.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# seperarting name and surname

# %%
#data['Surname'] = data.apply(lambda x: x.Name.split(',')[0], axis = 1)
#data['Name'] = data.apply(lambda x: x.Name.split(',')[1], axis = 1)

# %%
x= "Braund, Mr. Owen Harris"

# %%
 x.split(',')[0]
# Out:
# 'Braund'

# %%
lambda x: x.Name.split(',')[0]
# Out:
# <function __main__.<lambda>(x)>

# %%
titanic['surname']= titanic['name'].apply(lambda y: y.split(',')[0])

# %%
titanic.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked    surname
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
titanic['first_name']= titanic['name'].apply(lambda y: y.split(',')[1])

# %%
titanic.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked    surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
def findAgeGroup(age):
    if age<18:
        return 1
    elif age>=18 and age<40:
        return 2
    elif age>=40 and age<60:
        return 3
    else:
        return 4
#df['Age_group']=df['Age'].apply(lambda x: findAgeGroup(x))

# %%
findAgeGroup(61)
# Out:
# 4

# %%
titanic['age_group']= titanic['age'].apply(lambda y:findAgeGroup(y))

# %%
titanic.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked    surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
titanic.age_group.value_counts()
# Out:
# 2    438
# 4    203
# 3    137
# 1    113
# Name: age_group, dtype: int64

# %%
def age_group(age):
    if age<=18:
        return 'children'
    elif age>18 and age<45:
        return 'Adult'
    else:
        return 'old'

# %%
titanic['age_category']= titanic['age'].apply(lambda x: age_group(x))

# %%
titanic.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch            ticket     fare cabin embarked    surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0          PC 17599  71.2833   C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3      0            113803  53.1000  C123        S   Futrelle
# ...

# %%
titanic.drop(['ticket'], axis=1, inplace= True)

# %%
titanic.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch     fare cabin embarked    surname  \
# 0      0   7.2500   NaN        S     Braund
# 1      0  71.2833   C85        C    Cumings
# 2      0   7.9250   NaN        S  Heikkinen
# 3      0  53.1000  C123        S   Futrelle
# 4      0   8.0500   NaN        S      Allen
#
# ...

# %%
titanic=titanic.rename(columns= {'name': 'full_name'})

# %%
titanic.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            full_name     sex   age  sibsp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    parch     fare cabin embarked    surname  \
# 0      0   7.2500   NaN        S     Braund
# 1      0  71.2833   C85        C    Cumings
# 2      0   7.9250   NaN        S  Heikkinen
# 3      0  53.1000  C123        S   Futrelle
# 4      0   8.0500   NaN        S      Allen
#
# ...

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   passengerid   891 non-null    int64
#  1   survived      891 non-null    int64
#  2   pclass        891 non-null    int64
#  3   full_name     891 non-null    object
#  4   sex           891 non-null    object
#  5   age           714 non-null    float64
#  6   sibsp         891 non-null    int64
#  7   parch         891 non-null    int64
#  8   fare          891 non-null    float64
#  9   cabin         204 non-null    object
#  10  embarked      889 non-null    object
#  11  surname       891 non-null    object
#  12  first_name    891 non-null    object
#  13  age_group     891 non-null    int64
#  14  age_category  891 non-null    object
# dtypes: float64(2), int64(6), object(7)
# memory usage: 104.5+ KB

# %%
titanic.isnull().sum()
# Out:
# passengerid       0
# survived          0
# pclass            0
# full_name         0
# sex               0
# age             177
# sibsp             0
# parch             0
# fare              0
# cabin           687
# embarked          2
# surname           0
# first_name        0
# age_group         0
# age_category      0
# dtype: int64

# %%
titanic[titanic['age'].isna()]
# Out:
#      passengerid  survived  pclass                                 full_name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
titanic.age.isnull().sum()
# Out:
# 177

# %%
#lets fill 177 by the groupby features

# %%
titanic['age'].median()
# Out:
# 29.0

# %%
titanic['age'].min()
# Out:
# 0.42

# %%
titanic['age'].median()
# Out:
# 29.0

# %%
titanic.groupby(by=['sex'])['age'].transform('median')
# Out:
# 0      29.0
# 1      27.0
# 2      27.0
# 3      27.0
# 4      29.0
#        ...
# 886    29.0
# 887    27.0
# 888    27.0
# 889    29.0
# 890    29.0
# Name: age, Length: 891, dtype: float64

# %%
titanic['age']= titanic['age'].fillna(titanic.groupby(by=['sex'])['age'].transform('median'))

# %%
titanic.loc[[5]]
# Out:
#    passengerid  survived  pclass         full_name   sex   age  sibsp  parch  \
# 5            6         0       3  Moran, Mr. James  male  29.0      0      0
#
#      fare cabin embarked surname  first_name  age_group age_category
# 5  8.4583   NaN        Q   Moran   Mr. James          4          old

# %%
words=(lambda word, echo:word*echo)

# %%
words('i',5)
# Out:
# 'iiiii'

# %%
first= lambda names:names (',')[0]

# %%
print (first)
# Out:
# <function <lambda> at 0x000001BE0B5E18B0>

# %%
def bar_charts(df, feature):
    '''
    Inputs:
    df: Dataset
    feature: Name of Feature to Check With Survived
    '''
    _agg = {
        'PassengerId': 'count'
    }
    _groupby = ['Survived', feature]

    df_feature = df.groupby(by=_groupby).agg(_agg)
    # Find the percentage of people survived
    # df_feature = df_feature.groupby(level=0).apply(lambda x: 100 * x / float(x.sum()))
    
    ax = df_feature.unstack().plot(kind='bar', figsize=(15,6))
    plt.legend(list(df_feature.index.levels[1].unique()))
    plt.xlabel('Survived')
    plt.xticks(np.arange(2), ('No', 'Yes'))
    plt.show();

# %%
bar_charts(titanic, 'Pclass')

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.Age.isnull().sum()
# Out:
# 177

# %%
titanic["Age"].fillna(titanic['Age'].mean(),inplace=True)

# %%
titanic.Age.isnull().sum()
# Out:
# 0

# %%
import seaborn as sns

# %%
sns.boxplot(x=titanic['Age'], color='r', )
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(x=titanic['Age'])
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
import matplotlib.pyplot as plt

# %%
fig,ax= plt.subplots()
ax.bar(titanic['Age'],titanic['Fare'])
ax.set_xlabel('Age in Titanic')
ax.set_ylabel('Fare in Titanic')
plt.show()

# %%
c= titanic.corr()

# %%
c
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# Age             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SibSp          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.091566
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.heatmap(c, annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.hist(titanic['Age'], bins=10,histtype='step', density= True, linestyle='dotted')
plt.grid()

# %%
## 1.NEW

# %%
import pandas as pd

# %%
drinks= pd.read_csv('http://bit.ly/drinksbycountry')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['beer_servings']=drinks.beer_servings.astype(object)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                    object
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks['beer_servings']= drinks.beer_servings.astype(int)

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int32
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks.columns= drinks.columns.str.replace('_', ' ').str.replace('s','!').str.replace('continent','conti')

# %%
drinks.head()
# Out:
#        country  beer !erving!  !pirit !erving!  wine !erving!  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total litre! of pure alcohol   conti
# 0                           0.0    Asia
# 1                           4.9  Europe
# 2                           0.7  Africa
# 3                          12.4  Europe
# 4                           5.9  Africa

# %%
drinks.columns= drinks.columns.str.replace(' ', '_').str.replace('!','s').str.replace('conti','continental')

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continental'],
#       dtype='object')

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continental
# 0                           0.0        Asia
# 1                           4.9      Europe
# 2                           0.7      Africa
# 3                          12.4      Europe
# 4                           5.9      Africa

# %%
drinks.groupby('continental').wine_servings.mean()
# Out:
# continental
# Africa            16.264151
# Asia               9.068182
# Europe           142.222222
# North America     24.521739
# Oceania           35.625000
# South America     62.416667
# Name: wine_servings, dtype: float64

# %%
drinks.groupby('country').beer_servings.agg(['count', 'max', 'min', 'mean', 'median'])
# Out:
#              count  max  min   mean  median
# country
# Afghanistan      1    0    0    0.0     0.0
# Albania          1   89   89   89.0    89.0
# Algeria          1   25   25   25.0    25.0
# Andorra          1  245  245  245.0   245.0
# Angola           1  217  217  217.0   217.0
# ...            ...  ...  ...    ...     ...
# Venezuela        1  333  333  333.0   333.0
# Vietnam          1  111  111  111.0   111.0
# Yemen            1    6    6    6.0     6.0
# Zambia           1   32   32   32.0    32.0
# Zimbabwe         1   64   64   64.0    64.0
#
# [193 rows x 5 columns]

# %%
drinks.groupby('continental').mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continental
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continental
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
drinks.groupby('continental').agg(['min', 'max'])
# Out:
#                          country                 beer_servings       \
#                              min             max           min  max
# continental
# Africa                   Algeria        Zimbabwe             0  376
# Asia                 Afghanistan           Yemen             0  247
# Europe                   Albania  United Kingdom             0  361
# North America  Antigua & Barbuda             USA             1  285
# Oceania                Australia         Vanuatu             0  306
# South America          Argentina       Venezuela            93  333
#
#               spirit_servings      wine_servings       \
#                           min  max           min  max
# continental
# Africa                      0  152             0  233
# Asia                        0  326             0  123
# Europe                      0  373             0  370
# North America              68  438             1  100
# Oceania                     0  254             0  212
# ...

# %%
drinks.groupby('continental').mean().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='continental'>

# %%
# %matplotlib inline

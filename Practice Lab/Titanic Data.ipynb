# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('../Data/titanic_train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#How many rows and columns does it have?
df.shape
# Out:
# (891, 12)

# %%
#891 rows and 12 columns

# %%
#to see how many columns you have 
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#to see the rows
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
#in the specific columns to see how many data of each type we have

# %%
df[['Fare', 'Pclass']].value_counts()
# Out:
# Fare     Pclass
# 8.0500   3         43
# 13.0000  2         42
# 7.8958   3         38
# 7.7500   3         34
# 26.0000  2         29
#                    ..
# 25.5875  1          1
# 25.9250  1          1
# 7.7875   3          1
# 7.7417   3          1
# 7.7250   3          1
# Length: 255, dtype: int64

# %%
#to get the general description of the dataset
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#describing the age column only
df['Age'].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
#finding out the missing values
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#177 age missing, 687 cabin

# %%
#now we fill the age with mean and cabin with mode

df['Age'].isnull().sum()
# Out:
# 177

# %%
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Cabin'].isnull().sum()
# Out:
# 687

# %%
df['Cabin'].fillna(df['Cabin'].mode(), inplace=True)
df['Cabin'].isnull().sum()
# Out:
# 685

# %%
#we cannot because of string in the data

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  B96 B98        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250       G6        S
# 3      0            113803  53.1000     C123        S
# ...

# %%
#modifying the data inside

# %%
df['Sex']= df['Sex']. map({'male':'0' , 'female': '1'})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare    Cabin Embarked
# 0         A/5 21171   7.2500  B96 B98        S
# 1          PC 17599  71.2833      C85        C
# 2  STON/O2. 3101282   7.9250       G6        S
# 3            113803  53.1000     C123        S
# 4            373450   8.0500      NaN        S

# %%
#finding last name and first name/

# %%
df['last_name']=df['Name'].apply(lambda x: x.split(',')[0])

# %%
df['first_name']=df['Name'].apply(lambda x: ' '.join(x.split(',')[1:]))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare    Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500  B96 B98        S     Braund
# 1          PC 17599  71.2833      C85        C    Cumings
# 2  STON/O2. 3101282   7.9250       G6        S  Heikkinen
# 3            113803  53.1000     C123        S   Futrelle
# ...

# %%
#female with aged 60 and above
df[(df['Age']>60) & (df['Sex']=='1')]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#     Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked last_name  \
# 275   1  63.0      1      0   13502  77.9583    D7        S   Andrews
# 483   1  63.0      0      0    4134   9.5875   NaN        S   Turkula
# 829   1  62.0      0      0  113572  80.0000   B28      NaN     Stone
#
#                               first_name
# 275             Miss. Kornelia Theodosia
# 483                        Mrs. (Hedwig)
# 829   Mrs. George Nelson (Martha Evelyn)

# %%
df[(df['Age']<25)& (df['Sex']=='0')]
# Out:
#      PassengerId  Survived  Pclass                             Name Sex   Age  \
# 0              1         0       3          Braund, Mr. Owen Harris   0  22.0
# 7              8         0       3   Palsson, Master. Gosta Leonard   0   2.0
# 12            13         0       3   Saundercock, Mr. William Henry   0  20.0
# 16            17         0       3             Rice, Master. Eugene   0   2.0
# 27            28         0       1   Fortune, Mr. Charles Alexander   0  19.0
# ..           ...       ...     ...                              ...  ..   ...
# 861          862         0       2      Giles, Mr. Frederick Edward   0  21.0
# 864          865         0       2           Gill, Mr. John William   0  24.0
# 869          870         1       3  Johnson, Master. Harold Theodor   0   4.0
# 876          877         0       3    Gustafsson, Mr. Alfred Ossian   0  20.0
# 877          878         0       3             Petroff, Mr. Nedelio   0  19.0
#
# ...

# %%
#just selecting some columns

df1= df[["Age", "Pclass", "Sex"]]
df1.head()
# Out:
#     Age  Pclass Sex
# 0  22.0       3   0
# 1  38.0       1   1
# 2  26.0       3   1
# 3  35.0       1   1
# 4  35.0       3   0

# %%
#Renaming the columns

df2= df.rename(columns= {'Sex':'Gender','Name':'Full Name','last_name':'Surname','first_name':'Name'})
df2.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Full Name Gender   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris      0  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1  38.0      1
# 2                             Heikkinen, Miss. Laina      1  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1  35.0      1
# 4                           Allen, Mr. William Henry      0  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500  B96 B98        S     Braund
# 1      0          PC 17599  71.2833      C85        C    Cumings
# 2      0  STON/O2. 3101282   7.9250       G6        S  Heikkinen
# ...

# %%
#Deleting some columns

df4= df.drop(['Parch', 'SibSp', 'Cabin'], axis= 1)
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  \
# 0                            Braund, Mr. Owen Harris   0  22.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0
# 2                             Heikkinen, Miss. Laina   1  26.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0
# 4                           Allen, Mr. William Henry   0  35.0
#
#              Ticket     Fare Embarked  last_name  \
# 0         A/5 21171   7.2500        S     Braund
# 1          PC 17599  71.2833        C    Cumings
# 2  STON/O2. 3101282   7.9250        S  Heikkinen
# 3            113803  53.1000        S   Futrelle
# 4            373450   8.0500        S      Allen
#
#                                     first_name
# ...

# %%
#changing the columns into lower case
df.columns= [columns.lower() for columns in df]
print(df.columns)
# Out:
# Index(['passengerid', 'survived', 'pclass', 'name', 'sex', 'age', 'sibsp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked', 'last_name',
#        'first_name'],
#       dtype='object')

# %%
df.head()
# Out:
#    passengerid  survived  pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 name sex   age  sibsp  parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              ticket     fare    cabin embarked  last_name  \
# 0         A/5 21171   7.2500  B96 B98        S     Braund
# 1          PC 17599  71.2833      C85        C    Cumings
# 2  STON/O2. 3101282   7.9250       G6        S  Heikkinen
# 3            113803  53.1000     C123        S   Futrelle
# ...

# %%
df.columns= [columns.upper() for columns in df]
print(df.columns)
# Out:
# Index(['PASSENGERID', 'SURVIVED', 'PCLASS', 'NAME', 'SEX', 'AGE', 'SIBSP',
#        'PARCH', 'TICKET', 'FARE', 'CABIN', 'EMBARKED', 'LAST_NAME',
#        'FIRST_NAME'],
#       dtype='object')

# %%
df.corr()
# Out:
#              PASSENGERID  SURVIVED    PCLASS       AGE     SIBSP     PARCH  \
# PASSENGERID     1.000000 -0.005007 -0.035144  0.033207 -0.057527 -0.001652
# SURVIVED       -0.005007  1.000000 -0.338481 -0.069809 -0.035322  0.081629
# PCLASS         -0.035144 -0.338481  1.000000 -0.331339  0.083081  0.018443
# AGE             0.033207 -0.069809 -0.331339  1.000000 -0.232625 -0.179191
# SIBSP          -0.057527 -0.035322  0.083081 -0.232625  1.000000  0.414838
# PARCH          -0.001652  0.081629  0.018443 -0.179191  0.414838  1.000000
# FARE            0.012658  0.257307 -0.549500  0.091566  0.159651  0.216225
#
#                  FARE
# PASSENGERID  0.012658
# SURVIVED     0.257307
# PCLASS      -0.549500
# AGE          0.091566
# SIBSP        0.159651
# PARCH        0.216225
# FARE         1.000000

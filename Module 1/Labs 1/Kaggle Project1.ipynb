# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('../../DATA/titanic_train.csv')

# %%
#getting the top first 5 elements
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#top 10
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#tails
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#last 10 elements
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
#shape (Total rows, columns)
df.shape
# Out:
# (891, 12)

# %%
#to list all the columns
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
#to get the indexing
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
#to count the values in a particular column
df['Name'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object>

# %%
#to define the datframe (mean,median,std)
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#creating empty dataframe
df_empty= pd.DataFrame()
df_empty.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#creating from dictionary
student_dict={'Name':['A','B','C'],'Age':[24,18,17],'Roll':[1,2,3]}
df_student=pd.DataFrame(student_dict).reset_index(drop=True)
df_student.head()
# Out:
#   Name  Age  Roll
# 0    A   24     1
# 1    B   18     2
# 2    C   17     3

# %%
#null  value on whole data frame
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Age'].isnull().sum()
# Out:
# 177

# %%
#Impute null value
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Sex'].fillna(df['Sex'].mode(),inplace=True)
df['Sex'].isnull().sum()
# Out:
# 0

# %%
#modify/add new columns (Changing the value of male and female from sex column)
df['Sex']=df['Sex'].map({"male":'0',"female":"1"})
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
#accesssing the first and last name from name column
df['last_name']= df['Name'].apply(lambda x: x.split(',')[0])
df['first_name']= df['Name'].apply(lambda x:''.join (x.split (',')[1]))
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# ...

# %%
#Sets to 1 for men in 3rd class
df['Thrid&Men']=df.apply(lambda row: int(row['Pclass']==3 and row['Sex']=="0"),axis=1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# ...

# %%
def findAgeGroup(age):
    if age<18:
        return 1
    elif age>=18 and age<40:
        return 2
    elif age>=40 and age<60:
        return 3
    else:
        return 4
df['Age_group']=df['Age'].apply(lambda x: findAgeGroup(x))
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris   0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   1  38.0      1      0
# 2                             Heikkinen, Miss. Laina   1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   1  35.0      1      0
# 4                           Allen, Mr. William Henry   0  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  last_name  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# ...

# %%
#deleting columns
df=df.drop(['PassengerId'],axis=1)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6572\921934023.py in <module>
#       1 #deleting columns
# ----> 2 df=df.drop(['PassengerId'],axis=1)
#       3 df.head()
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ...

# %%
df=df.rename(columns={'Sex':'Gender','Name':'Full Name','last_name':'Surname','first_name':'Name'})
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
# ...

# %%
#Slicing
df_third_class= df[df['Pclass']==3].reset_index(drop=True)
df_third_class.head()
# Out:
#    Survived  Pclass                       Full Name Gender        Age  SibSp  \
# 0         0       3         Braund, Mr. Owen Harris      0  22.000000      1
# 1         1       3          Heikkinen, Miss. Laina      1  26.000000      0
# 2         0       3        Allen, Mr. William Henry      0  35.000000      0
# 3         0       3                Moran, Mr. James      0  29.699118      0
# 4         0       3  Palsson, Master. Gosta Leonard      0   2.000000      3
#
#    Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0      0         A/5 21171   7.2500   NaN        S     Braund
# 1      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 2      0            373450   8.0500   NaN        S      Allen
# 3      0            330877   8.4583   NaN        Q      Moran
# 4      1            349909  21.0750   NaN        S    Palsson
#
#                      Name  Thrid&Men  Age_group
# 0         Mr. Owen Harris          1          2
# ...

# %%
df_aged=df[(df['Age']>60) & (df['Gender']=="1")]
df_aged.head()
# Out:
#      Survived  Pclass                                  Full Name Gender   Age  \
# 275         1       1          Andrews, Miss. Kornelia Theodosia      1  63.0
# 483         1       3                     Turkula, Mrs. (Hedwig)      1  63.0
# 829         1       1  Stone, Mrs. George Nelson (Martha Evelyn)      1  62.0
#
#      SibSp  Parch  Ticket     Fare Cabin Embarked  Surname  \
# 275      1      0   13502  77.9583    D7        S  Andrews
# 483      0      0    4134   9.5875   NaN        S  Turkula
# 829      0      0  113572  80.0000   B28      NaN    Stone
#
#                                     Name  Thrid&Men  Age_group
# 275             Miss. Kornelia Theodosia          0          4
# 483                        Mrs. (Hedwig)          0          4
# 829   Mrs. George Nelson (Martha Evelyn)          0          4

# %%
#selecting some columns
df1=df[['Age','Pclass','Gender']]
df1.head()
# Out:
#     Age  Pclass Gender
# 0  22.0       3      0
# 1  38.0       1      1
# 2  26.0       3      1
# 3  35.0       1      1
# 4  35.0       3      0

# %%
#selecting numerical columns
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

df_num = df.select_dtypes(include=numerics)
df_num.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Thrid&Men  Age_group
# 0         0       3  22.0      1      0   7.2500          1          2
# 1         1       1  38.0      1      0  71.2833          0          2
# 2         1       3  26.0      0      0   7.9250          0          2
# 3         1       1  35.0      1      0  53.1000          0          2
# 4         0       3  35.0      0      0   8.0500          1          2

# %%
#selecting the objects
df_cat=df.select_dtypes(include=['object'])
df_cat.head()
# Out:
#                                            Full Name Gender            Ticket  \
# 0                            Braund, Mr. Owen Harris      0         A/5 21171
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1          PC 17599
# 2                             Heikkinen, Miss. Laina      1  STON/O2. 3101282
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1            113803
# 4                           Allen, Mr. William Henry      0            373450
#
#   Cabin Embarked    Surname                                         Name
# 0   NaN        S     Braund                              Mr. Owen Harris
# 1   C85        C    Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2   NaN        S  Heikkinen                                  Miss. Laina
# 3  C123        S   Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4   NaN        S      Allen                            Mr. William Henry

# %%
#Slicing using loc and iloc 
df.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
# ...

# %%
df_sub1=df.iloc[0:100,:]
df_sub1.head()
# Out:
#    Survived  Pclass                                          Full Name Gender  \
# 0         0       3                            Braund, Mr. Owen Harris      0
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...      1
# 2         1       3                             Heikkinen, Miss. Laina      1
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)      1
# 4         0       3                           Allen, Mr. William Henry      0
#
#     Age  SibSp  Parch            Ticket     Fare Cabin Embarked    Surname  \
# 0  22.0      1      0         A/5 21171   7.2500   NaN        S     Braund
# 1  38.0      1      0          PC 17599  71.2833   C85        C    Cumings
# 2  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3  35.0      1      0            113803  53.1000  C123        S   Futrelle
# 4  35.0      0      0            373450   8.0500   NaN        S      Allen
#
# ...

# %%
df_sub2=df.iloc[:250,[1,8]] 
df_sub2.head()
# Out:
#    Pclass     Fare
# 0       3   7.2500
# 1       1  71.2833
# 2       3   7.9250
# 3       1  53.1000
# 4       3   8.0500

# %%
df_sub3=df.loc[:500,:]

# %%
# Gender and age of age >50
df_sub4=df.loc[(df['Age']>50),['Gender','Age']]
df_sub4.head()
# Out:
#    Gender   Age
# 6       0  54.0
# 11      1  58.0
# 15      1  55.0
# 33      0  66.0
# 54      0  65.0

# %%
#adding a new data in  a row using append function
row= dict({'Age':24,'Full Name':'Peter','Survived':'Y'})
df= df.append (row, ignore_index= True)
df.tail()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_6572\2420506923.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df= df.append (row, ignore_index= True)
#     Survived  Pclass            Full Name Gender   Age  SibSp  Parch  Ticket  \
# 890        0     3.0  Dooley, Mr. Patrick      0  32.0    0.0    0.0  370376
# 891        Y     NaN                Peter    NaN  24.0    NaN    NaN     NaN
# 892        Y     NaN                Peter    NaN  24.0    NaN    NaN     NaN
# 893        Y     NaN                Peter    NaN  24.0    NaN    NaN     NaN
# 894        Y     NaN                Peter    NaN  24.0    NaN    NaN     NaN
#
#      Fare Cabin Embarked Surname          Name  Thrid&Men  Age_group
# 890  7.75   NaN        Q  Dooley   Mr. Patrick        1.0        2.0
# 891   NaN   NaN      NaN     NaN           NaN        NaN        NaN
# ...

# %%
df.loc[len(df.index)]=row
df.tail()
# Out:
#     Survived  Pclass Full Name Gender   Age  SibSp  Parch Ticket  Fare Cabin  \
# 891        Y     NaN     Peter    NaN  24.0    NaN    NaN    NaN   NaN   NaN
# 892        Y     NaN     Peter    NaN  24.0    NaN    NaN    NaN   NaN   NaN
# 893        Y     NaN     Peter    NaN  24.0    NaN    NaN    NaN   NaN   NaN
# 894        Y     NaN     Peter    NaN  24.0    NaN    NaN    NaN   NaN   NaN
# 895        Y     NaN     Peter    NaN  24.0    NaN    NaN    NaN   NaN   NaN
#
#     Embarked Surname Name  Thrid&Men  Age_group
# 891      NaN     NaN  NaN        NaN        NaN
# 892      NaN     NaN  NaN        NaN        NaN
# 893      NaN     NaN  NaN        NaN        NaN
# 894      NaN     NaN  NaN        NaN        NaN
# 895      NaN     NaN  NaN        NaN        NaN

# %%
#deleting last rows
df=df.drop(df.index[-1],axis=0)
df.tail()
# Out:
#     Survived  Pclass              Full Name Gender   Age  SibSp  Parch  \
# 889        1     1.0  Behr, Mr. Karl Howell      0  26.0    0.0    0.0
# 890        0     3.0    Dooley, Mr. Patrick      0  32.0    0.0    0.0
# 891        Y     NaN                  Peter    NaN  24.0    NaN    NaN
# 892        Y     NaN                  Peter    NaN  24.0    NaN    NaN
# 893        Y     NaN                  Peter    NaN  24.0    NaN    NaN
#
#      Ticket   Fare Cabin Embarked Surname              Name  Thrid&Men  \
# 889  111369  30.00  C148        C    Behr   Mr. Karl Howell        0.0
# 890  370376   7.75   NaN        Q  Dooley       Mr. Patrick        1.0
# 891     NaN    NaN   NaN      NaN     NaN               NaN        NaN
# 892     NaN    NaN   NaN      NaN     NaN               NaN        NaN
# 893     NaN    NaN   NaN      NaN     NaN               NaN        NaN
#
#      Age_group
# 889        2.0
# 890        2.0
# 891        NaN
# 892        NaN
# 893        NaN

# %%
#sorting by descending order (ascending=False==Descending)
df=df.sort_values(by=['Age'],ascending=False) 
df.head()
# Out:
#     Survived  Pclass                             Full Name Gender   Age  \
# 630        1     1.0  Barkworth, Mr. Algernon Henry Wilson      0  80.0
# 851        0     3.0                   Svensson, Mr. Johan      0  74.0
# 493        0     1.0               Artagaveytia, Mr. Ramon      0  71.0
# 96         0     1.0             Goldschmidt, Mr. George B      0  71.0
# 116        0     3.0                  Connors, Mr. Patrick      0  70.5
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked       Surname  \
# 630    0.0    0.0     27042  30.0000   A23        S     Barkworth
# 851    0.0    0.0    347060   7.7750   NaN        S      Svensson
# 493    0.0    0.0  PC 17609  49.5042   NaN        C  Artagaveytia
# 96     0.0    0.0  PC 17754  34.6542    A5        C   Goldschmidt
# 116    0.0    0.0    370369   7.7500   NaN        Q       Connors
#
#                            Name  Thrid&Men  Age_group
# 630   Mr. Algernon Henry Wilson        0.0        4.0
# ...

# %%
#group-by(getting the value i.e.3 and groupping them together from Pclass)
groups= df.groupby(['Pclass'])
groups.get_group(3)
# Out:
#     Survived  Pclass                        Full Name Gender    Age  SibSp  \
# 851        0     3.0              Svensson, Mr. Johan      0  74.00    0.0
# 116        0     3.0             Connors, Mr. Patrick      0  70.50    0.0
# 280        0     3.0                 Duane, Mr. Frank      0  65.00    0.0
# 483        1     3.0           Turkula, Mrs. (Hedwig)      1  63.00    0.0
# 326        0     3.0        Nysveen, Mr. Johan Hansen      0  61.00    0.0
# ..       ...     ...                              ...    ...    ...    ...
# 172        1     3.0     Johnson, Miss. Eleanor Ileen      1   1.00    1.0
# 164        0     3.0     Panula, Master. Eino Viljami      0   1.00    4.0
# 469        1     3.0    Baclini, Miss. Helene Barbara      1   0.75    2.0
# 644        1     3.0           Baclini, Miss. Eugenie      1   0.75    2.0
# 803        1     3.0  Thomas, Master. Assad Alexander      0   0.42    0.0
#
#      Parch   Ticket     Fare Cabin Embarked   Surname  \
# ...

# %%
#grouping by pclass
df_grp1=df.groupby(['Pclass'])
df_grp1['Age'].mean()
# Out:
# Pclass
# 1.0    37.048118
# 2.0    29.866958
# 3.0    26.403259
# Name: Age, dtype: float64

# %%
df=train.copy()
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6572\1742540565.py in <module>
# ----> 1 df=train.copy()
#       2 df.head()
#
# NameError: name 'train' is not defined

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_survive= df[(df['Sex']=='female') & (df['Survived']==1)]
df_survive
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Survived']==1].Sex.value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
df['Fare'].mean()
# Out:
# 32.2042079685746

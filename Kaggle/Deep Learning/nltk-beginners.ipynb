# %%
import nltk

# %%
text = "Once when King Krishnadevaraya had gone to survey the jail, two burglars who were prisoners there, asked for his mercy. They told him that they were experts at burglary and could help the king in catching other thieves.The king being a kind ruler asked his guards to release them but with a condition. He told the burglars that he would release them and appoint them as his spies only if they could break into his advisor Tenali Raman’s house and steal valuables from there. The thieves agreed for the challenge.That same night the two thieves went to Tenali Raman’s house and hid behind some bushes. After dinner, when Tenali Raman came out for a stroll, he heard some rustling in the bushes. He at once perceived the existence of thieves in his garden."
text = text.lower()

text
# Out:
# 'once when king krishnadevaraya had gone to survey the jail, two burglars who were prisoners there, asked for his mercy. they told him that they were experts at burglary and could help the king in catching other thieves.the king being a kind ruler asked his guards to release them but with a condition. he told the burglars that he would release them and appoint them as his spies only if they could break into his advisor tenali raman’s house and steal valuables from there. the thieves agreed for the challenge.that same night the two thieves went to tenali raman’s house and hid behind some bushes. after dinner, when tenali raman came out for a stroll, he heard some rustling in the bushes. he at once perceived the existence of thieves in his garden.'

# %%
from nltk import sent_tokenize

# Tokenize sentences
sent_text = sent_tokenize(text)

sent_text
# Out:
# ['once when king krishnadevaraya had gone to survey the jail, two burglars who were prisoners there, asked for his mercy.',
#  'they told him that they were experts at burglary and could help the king in catching other thieves.the king being a kind ruler asked his guards to release them but with a condition.',
#  'he told the burglars that he would release them and appoint them as his spies only if they could break into his advisor tenali raman’s house and steal valuables from there.',
#  'the thieves agreed for the challenge.that same night the two thieves went to tenali raman’s house and hid behind some bushes.',
#  'after dinner, when tenali raman came out for a stroll, he heard some rustling in the bushes.',
#  'he at once perceived the existence of thieves in his garden.']

# %%
from nltk import word_tokenize
# Do the word-tokenization from sentence-tokenization
for sent in sent_text:
    word_text = word_tokenize(sent)
    print(word_text)
# Out:
# ['once', 'when', 'king', 'krishnadevaraya', 'had', 'gone', 'to', 'survey', 'the', 'jail', ',', 'two', 'burglars', 'who', 'were', 'prisoners', 'there', ',', 'asked', 'for', 'his', 'mercy', '.']
# ['they', 'told', 'him', 'that', 'they', 'were', 'experts', 'at', 'burglary', 'and', 'could', 'help', 'the', 'king', 'in', 'catching', 'other', 'thieves.the', 'king', 'being', 'a', 'kind', 'ruler', 'asked', 'his', 'guards', 'to', 'release', 'them', 'but', 'with', 'a', 'condition', '.']
# ['he', 'told', 'the', 'burglars', 'that', 'he', 'would', 'release', 'them', 'and', 'appoint', 'them', 'as', 'his', 'spies', 'only', 'if', 'they', 'could', 'break', 'into', 'his', 'advisor', 'tenali', 'raman', '’', 's', 'house', 'and', 'steal', 'valuables', 'from', 'there', '.']
# ['the', 'thieves', 'agreed', 'for', 'the', 'challenge.that', 'same', 'night', 'the', 'two', 'thieves', 'went', 'to', 'tenali', 'raman', '’', 's', 'house', 'and', 'hid', 'behind', 'some', 'bushes', '.']
# ['after', 'dinner', ',', 'when', 'tenali', 'raman', 'came', 'out', 'for', 'a', 'stroll', ',', 'he', 'heard', 'some', 'rustling', 'in', 'the', 'bushes', '.']
# ['he', 'at', 'once', 'perceived', 'the', 'existence', 'of', 'thieves', 'in', 'his', 'garden', '.']

# %% [markdown]
# ## Stop Word Removal

# %%
from nltk.corpus import stopwords
stopwords_en = stopwords.words('english')

# %%
stopwords_en # pre-defined set of stop words in the english language
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
from string import punctuation

# %%
print('From string punctuation:',type(punctuation),punctuation)
# Out:
# From string punctuation: <class 'str'> !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
stopwords_en = set(stopwords_en)
stopwords_en_with_punct = stopwords_en.union(set(punctuation))
print(stopwords_en_with_punct)
# Out:
# {'the', "wouldn't", 'further', 'from', "shouldn't", 'has', "weren't", 'our', 'my', 'you', 'yourself', 'out', 'theirs', 't', 'after', 'ain', "haven't", 'wouldn', 'not', 'will', 'to', 're', "won't", "mightn't", 'and', 'few', '$', "didn't", 'off', 'i', '>', 'we', 'because', 'its', ',', 'so', '@', ';', 'isn', 'aren', 'if', 'should', 'weren', 'those', 'while', 'nor', 'in', 'same', '^', '\\', 'most', 'what', 'being', 'each', 'below', 'other', "'", '<', '}', 'had', 'myself', "shan't", 'yourselves', "you'd", 'hers', '(', '[', 'having', 'do', 'where', 'couldn', 'won', 'who', 'shan', '-', 'why', 'o', 'just', "should've", 'as', 'hadn', 'both', 'their', "she's", 'can', '`', "hasn't", '"', 'were', 'didn', 'me', 'such', 'doesn', 'was', 'mightn', "you're", "aren't", 'down', 'wasn', 'very', ']', 'up', 'she', "mustn't", 'whom', 'he', 'about', 'ours', 'before', "isn't", 'over', 'here', '%', 'himself', 'ma', 'how', 'at', '~', 'any', 'above', 'on', 'does', 'which', 'that', 'through', 'needn', 'again', 'his', "couldn't", '_', 'by', 'during', ':', 'm', 'no', 'once', 'is', 'against', 'mustn', 'herself', 'did', "that'll", "needn't", 's', 'for', '*', '.', 'y', "doesn't", 'him', 'her', 'own', 'too', 'an', "you'll", 'don', 'doing', 'itself', 'am', 'be', 'some', 'they', 've', 'shouldn', '/', '!', 'then', 'more', "wasn't", 'll', ')', 'yours', 'it', '=', '{', 'been', "you've", 'your', 'until', 'these', "don't", 'of', '|', 'between', 'with', 'into', '+', '#', '?', 'd', 'this', 'there', 'ourselves', 'a', 'are', 'hasn', 'haven', 'or', 'than', 'now', "hadn't", 'them', "it's", 'themselves', 'have', 'all', '&', 'only', 'but', 'when', 'under'}

# %%
word_text2 = word_tokenize(text)

# %%
word_text2
# Out:
# ['once',
#  'when',
#  'king',
#  'krishnadevaraya',
#  'had',
#  'gone',
#  'to',
#  'survey',
#  'the',
#  'jail',
#  ',',
#  'two',
#  'burglars',
#  'who',
#  'were',
#  'prisoners',
#  'there',
#  ',',
#  'asked',
#  'for',
#  'his',
#  'mercy',
#  '.',
#  'they',
#  'told',
#  'him',
#  'that',
#  'they',
#  'were',
#  'experts',
#  'at',
#  'burglary',
#  'and',
#  'could',
#  'help',
#  'the',
#  'king',
#  'in',
#  'catching',
#  'other',
#  'thieves.the',
#  'king',
#  'being',
#  'a',
#  'kind',
#  'ruler',
#  'asked',
#  'his',
#  'guards',
#  'to',
#  'release',
#  'them',
#  'but',
#  'with',
#  'a',
#  'condition',
#  '.',
#  'he',
#  'told',
#  'the',
#  'burglars',
#  'that',
#  'he',
#  'would',
#  'release',
#  'them',
#  'and',
#  'appoint',
#  'them',
#  'as',
#  'his',
#  'spies',
#  'only',
#  'if',
#  'they',
#  'could',
#  'break',
#  'into',
#  'his',
#  'advisor',
#  'tenali',
#  'raman',
#  '’',
#  's',
#  'house',
#  'and',
#  'steal',
#  'valuables',
#  'from',
#  'there',
#  '.',
#  'the',
#  'thieves',
#  'agreed',
#  'for',
#  'the',
#  'challenge.that',
#  'same',
#  'night',
#  'the',
#  'two',
#  'thieves',
#  'went',
#  'to',
#  'tenali',
#  'raman',
#  '’',
#  's',
#  'house',
#  'and',
#  'hid',
#  'behind',
#  'some',
#  'bushes',
#  '.',
#  'after',
#  'dinner',
#  ',',
#  'when',
#  'tenali',
#  'raman',
#  'came',
#  'out',
#  'for',
#  'a',
#  'stroll',
#  ',',
#  'he',
#  'heard',
#  'some',
#  'rustling',
#  'in',
#  'the',
#  'bushes',
#  '.',
#  'he',
#  'at',
#  'once',
#  'perceived',
#  'the',
#  'existence',
#  'of',
#  'thieves',
#  'in',
#  'his',
#  'garden',
#  '.']

# %%
# Weed-out words that are not stopwords
word_text2_filtered = [word for word in word_text2 if word not in stopwords_en_with_punct]

# %% [markdown]
# ## Stemming & Lemmatization

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

for word in word_text2_filtered:
    print(stemmer.stem(word))
# Out:
# king
# krishnadevaraya
# gone
# survey
# jail
# two
# burglar
# prison
# ask
# merci
# told
# expert
# burglari
# could
# help
# king
# catch
# thieves.th
# king
# kind
# ruler
# ask
# guard
# releas
# condit
# told
# burglar
# would
# releas
# appoint
# spi
# could
# break
# advisor
# tenali
# raman
# ’
# hous
# steal
# valuabl
# thiev
# agre
# challenge.that
# night
# two
# thiev
# went
# tenali
# raman
# ’
# hous
# hid
# behind
# bush
# dinner
# tenali
# raman
# came
# stroll
# heard
# rustl
# bush
# perceiv
# exist
# thiev
# garden

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

for word in word_text2_filtered:
    print(lemmatizer.lemmatize(word))
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# king
# krishnadevaraya
# gone
# survey
# jail
# two
# burglar
# prisoner
# asked
# mercy
# told
# expert
# burglary
# could
# help
# king
# catching
# thieves.the
# king
# kind
# ruler
# asked
# guard
# release
# condition
# told
# burglar
# would
# release
# appoint
# spy
# could
# break
# advisor
# tenali
# raman
# ’
# house
# steal
# valuable
# thief
# agreed
# challenge.that
# night
# two
# thief
# went
# tenali
# raman
# ’
# house
# hid
# behind
# bush
# dinner
# tenali
# raman
# came
# stroll
# heard
# rustling
# bush
# perceived
# existence
# thief
# garden

# %% [markdown]
# ## POS Tagging

# %%
nltk.download('averaged_perceptron_tagger')
tagged_text = nltk.pos_tag(word_text2_filtered)
tagged_text
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /usr/share/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [('king', 'VBG'),
#  ('krishnadevaraya', 'NN'),
#  ('gone', 'VBN'),
#  ('survey', 'NN'),
#  ('jail', 'NN'),
#  ('two', 'CD'),
#  ('burglars', 'NNS'),
#  ('prisoners', 'NNS'),
#  ('asked', 'VBD'),
#  ('mercy', 'NNS'),
#  ('told', 'VBD'),
#  ('experts', 'NNS'),
#  ('burglary', 'NN'),
#  ('could', 'MD'),
#  ('help', 'VB'),
#  ('king', 'VBG'),
#  ('catching', 'VBG'),
#  ('thieves.the', 'JJ'),
#  ('king', 'NN'),
#  ('kind', 'NN'),
#  ('ruler', 'NN'),
#  ('asked', 'VBD'),
#  ('guards', 'NNS'),
#  ('release', 'NN'),
#  ('condition', 'NN'),
#  ('told', 'VBD'),
#  ('burglars', 'NNS'),
#  ('would', 'MD'),
#  ('release', 'VB'),
#  ('appoint', 'NN'),
#  ('spies', 'NNS'),
#  ('could', 'MD'),
#  ('break', 'VB'),
#  ('advisor', 'JJ'),
#  ('tenali', 'JJ'),
#  ('raman', 'NN'),
#  ('’', 'NNP'),
#  ('house', 'NN'),
#  ('steal', 'NN'),
#  ('valuables', 'VBZ'),
#  ('thieves', 'NNS'),
#  ('agreed', 'VBD'),
#  ('challenge.that', 'RB'),
#  ('night', 'NN'),
#  ('two', 'CD'),
#  ('thieves', 'NNS'),
#  ('went', 'VBD'),
#  ('tenali', 'JJ'),
#  ('raman', 'NN'),
#  ('’', 'NNP'),
#  ('house', 'NN'),
#  ('hid', 'NN'),
#  ('behind', 'IN'),
#  ('bushes', 'NNS'),
#  ('dinner', 'VBP'),
#  ('tenali', 'JJ'),
#  ('raman', 'NN'),
#  ('came', 'VBD'),
#  ('stroll', 'RB'),
#  ('heard', 'VBN'),
#  ('rustling', 'VBG'),
#  ('bushes', 'NNS'),
#  ('perceived', 'VBD'),
#  ('existence', 'NN'),
#  ('thieves', 'NNS'),
#  ('garden', 'VBP')]

# %% [markdown]
# ## POS taggers list

# %% [markdown]
# * CC coordinating conjunction

# %% [markdown]
# * CD cardinal digit

# %% [markdown]
# * DT determiner

# %% [markdown]
# * EX existential there (like: “there is” … think of it like “there exists”)

# %% [markdown]
# * FW foreign word

# %% [markdown]
# * IN preposition/subordinating conjunction

# %% [markdown]
# * JJ adjective ‘big’

# %% [markdown]
# * JJR adjective, comparative ‘bigger’

# %% [markdown]
# * JJS adjective, superlative ‘biggest’

# %% [markdown]
# * LS list marker 1)

# %% [markdown]
# * MD modal could, will

# %% [markdown]
# * NN noun, singular ‘desk’

# %% [markdown]
# * NNS noun plural ‘desks’

# %% [markdown]
# * NNP proper noun, singular ‘Harrison’

# %% [markdown]
# * NNPS proper noun, plural ‘Americans’

# %% [markdown]
# * PDT predeterminer ‘all the kids’

# %% [markdown]
# * POS possessive ending parent’s

# %% [markdown]
# * PRP personal pronoun I, he, she

# %% [markdown]
# * PRP$ possessive pronoun my, his, hers

# %% [markdown]
# * RB adverb very, silently,

# %% [markdown]
# * RBR adverb, comparative better

# %% [markdown]
# * RBS adverb, superlative best

# %% [markdown]
# * RP particle give up

# %% [markdown]
# * TO, to go ‘to’ the store.

# %% [markdown]
# * UH interjection, errrrrrrrm

# %% [markdown]
# * VB verb, base form take

# %% [markdown]
# * VBD verb, past tense took

# %% [markdown]
# * VBG verb, gerund/present participle taking

# %% [markdown]
# * VBN verb, past participle taken

# %% [markdown]
# * VBP verb, sing. present, non-3d take

# %% [markdown]
# * VBZ verb, 3rd person sing. present takes

# %% [markdown]
# * WDT wh-determiner which

# %% [markdown]
# * WP wh-pronoun who, what

# %% [markdown]
# * WP$ possessive wh-pronoun whose

# %% [markdown]
# * WRB wh-abverb where, when

# %% [markdown]
# ## Named Entity Recognition

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
ne_chunked = nltk.ne_chunk(tagged_text)
print(ne_chunked)
# Out:
# (S
#   king/VBG
#   krishnadevaraya/NN
#   gone/VBN
#   survey/NN
#   jail/NN
#   two/CD
#   burglars/NNS
#   prisoners/NNS
#   asked/VBD
#   mercy/NNS
#   told/VBD
#   experts/NNS
#   burglary/NN
#   could/MD
#   help/VB
#   king/VBG
#   catching/VBG
#   thieves.the/JJ
#   king/NN
#   kind/NN
#   ruler/NN
#   asked/VBD
#   guards/NNS
#   release/NN
#   condition/NN
#   told/VBD
#   burglars/NNS
#   would/MD
#   release/VB
#   appoint/NN
#   spies/NNS
#   could/MD
#   break/VB
#   advisor/JJ
#   tenali/JJ
#   raman/NN
#   ’/NNP
#   house/NN
#   steal/NN
#   valuables/VBZ
#   thieves/NNS
#   agreed/VBD
#   challenge.that/RB
#   night/NN
#   two/CD
#   thieves/NNS
#   went/VBD
#   tenali/JJ
#   raman/NN
#   ’/NNP
#   house/NN
#   hid/NN
#   behind/IN
#   bushes/NNS
#   dinner/VBP
#   tenali/JJ
#   raman/NN
#   came/VBD
#   stroll/RB
#   heard/VBN
#   rustling/VBG
#   bushes/NNS
#   perceived/VBD
#   existence/NN
#   thieves/NNS
#   garden/VBP)

# %%
named_entities = []

for tagged_tree in ne_chunked:
    if hasattr(tagged_tree , 'label'):
        entity_name =' '.join(c[0] for c in tagged_tree.leaves())
        entity_type = tagged_tree.label()
        named_entities.append((entity_name,entity_type))


print(named_entities)
# Out:
# []

# %%
text3 = 'Sundar is the CEO of Google is an American company.'

tokenised = nltk.word_tokenize(text3)
tagged_text3 = nltk.pos_tag(tokenised)

ne_chunked = nltk.ne_chunk(tagged_text3)

named_entities = []

for tagged_tree in ne_chunked:
    if hasattr(tagged_tree , 'label'):
        entity_name =' '.join(c[0] for c in tagged_tree.leaves())
        entity_type = tagged_tree.label()
        named_entities.append((entity_name,entity_type))
        
print(named_entities)
# Out:
# [('Sundar', 'GPE'), ('CEO of Google', 'ORGANIZATION'), ('American', 'GPE')]

# %% [markdown]
# ## End Of Text Processing Pipeline Section
